# %% [markdown]
# # Blue Eye Labs- Coding challenges
#
# ## Python Sets — Practice Challenges
#
# This notebook contains **3 beginner-friendly challenges** on Python sets.
#
# ### Topics covered
# - Creating sets
# - Removing duplicate values
# - Adding and removing elements
# - Set mathematical operations
# - Membership checking with `in` and `not in`

# %% [markdown]
# ## Challenge 1 — Clean and Modify a Set
#
# You are given a collection of student names. Some names appear more than once.
#
# ### Your tasks
# 1. Create a set from the given list to automatically remove duplicates.
# 2. Add `"David"` to the set.
# 3. Remove `"Bob"` from the set.
# 4. Check whether `"Alice"` is still a member of the set.
#
# **Expected concepts:** `set()`, `add()`, `remove()` or `discard()`, `in`
#
# ```python
# students = ["Alice", "Bob", "Charlie", "Alice", "Bob"]
#
# # Write your solution below
# ```

# %%
students = ["Alice", "Bob", "Charlie", "Alice", "Bob"]

# Your solution:

# %% [markdown]
# ### Challenge 2 — Compare Two Sets
#
# Two groups of students are attending different Python workshops.
#
# ```python
# morning = {"Alice", "Bob", "Charlie", "David"}
# evening = {"Charlie", "David", "Emma", "Frank"}
# ```
#
# ### Your tasks
# 1. Find all students attending **either** workshop.
# 2. Find students attending **both** workshops.
# 3. Find students attending the morning workshop but **not** the evening workshop.
# 4. Check whether `"Emma"` is a member of the morning workshop.
#
# **Restriction:** Do not use loops.
#
# **Hint:** Try both operator syntax such as `|`, `&`, `-` and the corresponding set methods.

# %%
morning = {"Alice", "Bob", "Charlie", "David"}
evening = {"Charlie", "David", "Emma", "Frank"}

# Write your solution below

# %% [markdown]
# ### Challenge 3 — Membership Checking
#
# You have a set of available programming languages:
#
# ```python
# languages = {"Python", "Java", "C++", "JavaScript"}
# ```
#
# ### Your tasks
# Use membership operators to check:
#
# 1. Is `"Python"` available?
# 2. Is `"Ruby"` available?
# 3. Is `"Java"` **not** available?
# 4. Add `"Ruby"` to the set and check again whether `"Ruby"` is available.
#
# **Remember:** Use `in` and `not in`.
#
# **Restriction:** No loops.

# %%
languages = {"Python", "Java", "C++", "JavaScript"}

# Write your solution below

# %% [markdown]
# ## ⭐ Bonus Challenge — Frozen Set
#
# Create a frozen set containing:
#
# ```python
# {"Python", "Java", "C++"}
# ```
#
# Then:
#
# 1. Check whether `"Python"` is a member of the frozen set.
# 2. Try adding `"Ruby"` to it.
# 3. Observe the error and explain why a `frozenset` cannot be modified.
#
# ```python
# # Write your solution below
# ```

# %%
# Write your solution below

# %% [markdown]
# ## Quick Reminder
#
# | Concept | Example |
# |---|---|
# | Create a set | `set([1, 2, 2, 3])` |
# | Add | `my_set.add(4)` |
# | Remove | `my_set.remove(4)` |
# | Union | `set_a \| set_b` |
# | Intersection | `set_a & set_b` |
# | Difference | `set_a - set_b` |
# | Membership | `item in my_set` |
# | Not a member | `item not in my_set` |
# | Frozen set | `frozenset([1, 2, 3])` |
#
# **Remember:** These exercises are intentionally designed for training purpose only
