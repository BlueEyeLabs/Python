# %% [markdown]
# # ![Blue-Eye Media Logo](your_logo_file_path_or_URL)
#
# # Python Lists - Beginner Friendly Practice
# Learn with Blue‑Eye Labs ✦ Official Content

# %% [markdown]
# ## 🐍 Introduction
# Lists are ordered, mutable collections in Python. They can store numbers, strings, booleans, or even other lists.
#
# Example:

# %%
my_list = [10, 20, 30, "Python", True]
print(my_list)
# Out:
# [10, 20, 30, 'Python', True]

# %% [markdown]
# ## 🔎 Indexing & Slicing
# You can access elements by index. Positive indices start at 0, negative indices start at -1.

# %%
numbers = [10, 20, 30, 40, 50]
print(numbers[0])   # First element
print(numbers[-1])  # Last element
print(numbers[1:4]) # Slice
# Out:
# 10
# 50
# [20, 30, 40]

# %% [markdown]
# ## 🔄 List Operations
# Lists can be modified with methods like append, extend, remove, sort, and reverse.

# %%
fruits = ["apple", "banana", "cherry"]
fruits.append("orange")
print(fruits)

fruits.remove("banana")
print(fruits)

numbers = [5, 2, 9, 1]
numbers.sort()
print(numbers)
numbers.reverse()
print(numbers)
# Out:
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'cherry', 'orange']
# [1, 2, 5, 9]
# [9, 5, 2, 1]

# %% [markdown]
# ## 🧠 Practice Exercises
# 1. Create a list of 5 integers and print the sum.
# 2. Reverse a list without using `reverse()`.
# 3. Print names starting with “A” from a list.

# %% [markdown]
# ## 🎯 Challenge
# Write a program that:
# - Takes a list of integers from the user.
# - Prints average, max, and min.
# - Removes duplicates.
